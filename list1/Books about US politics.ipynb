# %%
# Books about US politics from http://www-personal.umich.edu/~mejn/netdata/

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
# read dataset in gml
g = nx.read_gml("polbooks.gml")

# %%
# simple graph
plt.figure(figsize=(48, 36))
nx.draw(g, with_labels=True, node_color='orange', node_size=400, edge_color='black', linewidths=1, font_size=15)
# Out:
# /home/bartosz/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %%
from pyvis import network as net

# %%
# new graph from old one
H = net.Network(height="750px", width="100%")
H.from_nx(g)

# %%
# showing graph with control buttons
H.show_buttons(filter_=['physics'])
H.show('example.html')
